# %%
from main import Solver
import torch
from synth_data import create_synthData_new, create_synthData_multi
from validation_method import FS_MCC
import numpy as np

# Hyper Params Section
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using", torch.cuda.device_count(), "GPUs")

Solver = Solver(device)
## Evaluation params
ACC_list = []
FS_list = []
MCC_list = []
# Out:
# Using 0 GPUs

# %%
## Scenario 1
## Evaluation params
ACC_list = []
FS_list = []
MCC_list = []

for i in range(4,11,2):
    print(i)
    FS = []
    MCC = []
    ACC = []
    N = 400
    views = create_synthData_multi(i=i, data_type=1,N=400, p=20, q=20, r=20)    
    print(f'input views shape :')
    for i, view in enumerate(views):
        print(f'view_{i} :  {view.shape}')
        view = view.to("cpu")

    ## train hyper
    b0, obj = Solver.tune_hyper(x_list=views, set_params=5,iter=50)
    print(b0)

    print("SNGCCA Started!")
    for rep in range(1):
        if (rep + 1) % 100 == 0:
            print("REP=", rep + 1)

        ## fit results
        u = Solver._get_outputs(views, 1e-7, 100, b0)

        Label = torch.cat([torch.ones(2, dtype=torch.bool), torch.zeros(18, dtype=torch.bool)])
        acc,f1,mcc = FS_MCC(u, Label)
        ACC.append(acc)
        FS.append(f1)
        MCC.append(mcc)

    macc = np.mean(ACC)
    sdacc = np.std(ACC)
    print(macc, sdacc)
    ACC_list.append([macc,sdacc])

    mf = np.mean(FS)
    sdf = np.std(FS)
    print(mf, sdf)
    FS_list.append([mf,sdf])

    mmcc = np.mean(MCC)
    sdmcc = np.std(MCC)
    print(mmcc, sdmcc)
    MCC_list.append([mmcc, sdmcc])
# Out:
# 4
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.1097)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.2369)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.2383)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.2423)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.2363)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2359)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2248)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2321)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.1963)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.2361)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.2310)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.2336)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.2362)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.2373)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.2353)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2332)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2353)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2374)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.2284)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.2347)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.2317)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.2313)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.2332)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.2337)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.2345)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.2329)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.2354)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.2364)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.2328)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.2321)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.2324)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.1939)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.2338)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.2360)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.2330)
# Finish Tuning!
# (1.0, 1.0, 18.803015465431965)
# SNGCCA Started!
# 0.95 0.0
# 0.8 0.0
# 0.7934920476158722 0.0
# 6
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0825)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.1895)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.1907)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.1881)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.1949)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2212)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2222)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2237)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.2249)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.2177)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.2176)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.2200)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.1861)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.2160)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.2096)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2182)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2196)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2183)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.2199)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.2161)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.2171)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.2159)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.2120)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.2237)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.2158)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.2160)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.2188)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.2135)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.2156)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.2134)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.2176)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.2187)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.2131)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.2160)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.2173)
# Finish Tuning!
# (1.0, 2.6591479484724942, 49.99999999999999)
# SNGCCA Started!
# 0.85 0.0
# 0.5714285714285715 0.0
# 0.5773502691896257 0.0
# 8
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.1223)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.1568)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.1450)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.1217)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.1186)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.1768)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.1971)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2081)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.1470)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.1973)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.1628)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.1789)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.1971)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.1866)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.1938)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2041)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2130)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2087)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.2085)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.2060)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.2101)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.2034)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.2087)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.2022)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.2069)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.2055)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.2034)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.2015)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.2049)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.2085)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.2091)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.2080)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.2063)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.2073)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.2017)
# Finish Tuning!
# (2.6591479484724942, 2.6591479484724942, 7.071067811865475)
# SNGCCA Started!
# 0.75 0.0
# 0.4444444444444445 0.0
# 0.454256762579498 0.0
# 10
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0786)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.1352)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.1429)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.0994)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.1356)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.1729)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.1904)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.1911)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.1755)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.1795)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.1748)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.1819)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.1848)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.1595)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.1801)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.2138)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.2109)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.2072)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.2114)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.2194)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.2202)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.2172)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.2229)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.2128)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.2181)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.2184)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.2193)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.2181)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.2099)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.2149)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.2206)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.2196)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.2176)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.2117)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.2203)
# Finish Tuning!
# (2.6591479484724942, 18.803015465431965, 18.803015465431965)
# SNGCCA Started!
# 0.6666666666666666 0.0
# 0.375 0.0
# 0.38118124993124375 0.0

# %%
print(ACC_list)
print(FS_list)
print(MCC_list)
# Out:
# [[0.95, 0.0], [0.85, 0.0], [0.75, 0.0], [0.6666666666666666, 0.0]]
# [[0.8, 0.0], [0.5714285714285715, 0.0], [0.4444444444444445, 0.0], [0.375, 0.0]]
# [[0.7934920476158722, 0.0], [0.5773502691896257, 0.0], [0.454256762579498, 0.0], [0.38118124993124375, 0.0]]

# %%
## Scenario 2
## Evaluation params
ACC_list = []
FS_list = []
MCC_list = []

for i in range(4,11,2):
    print(i)
    FS = []
    MCC = []
    ACC = []
    N = 400
    views = create_synthData_multi(i=i, data_type=2,N=400, p=20, q=20, r=20)    
    print(f'input views shape :')
    for i, view in enumerate(views):
        print(f'view_{i} :  {view.shape}')
        view = view.to("cpu")

    ## train hyper
    b0, obj = Solver.tune_hyper(x_list=views, set_params=5,iter=50)
    print(b0)

    print("SNGCCA Started!")
    for rep in range(1):
        if (rep + 1) % 100 == 0:
            print("REP=", rep + 1)

        ## fit results
        u = Solver._get_outputs(views, 1e-7, 100, b0)

        Label = torch.cat([torch.ones(2, dtype=torch.bool), torch.zeros(18, dtype=torch.bool)])
        acc,f1,mcc = FS_MCC(u, Label)
        ACC.append(acc)
        FS.append(f1)
        MCC.append(mcc)

    macc = np.mean(ACC)
    sdacc = np.std(ACC)
    print(macc, sdacc)
    ACC_list.append([macc,sdacc])

    mf = np.mean(FS)
    sdf = np.std(FS)
    print(mf, sdf)
    FS_list.append([mf,sdf])

    mmcc = np.mean(MCC)
    sdmcc = np.std(MCC)
    print(mmcc, sdmcc)
    MCC_list.append([mmcc, sdmcc])
# Out:
# 4
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0064)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.0089)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.0078)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.0077)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.0068)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0610)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0283)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0083)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0108)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.0591)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.0091)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.0115)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.0077)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.0082)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.0079)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0495)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0081)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0574)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0488)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.0568)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.0085)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.0083)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.1440)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.0548)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.1103)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.0072)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.0100)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.0488)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.0064)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.0086)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.0077)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.0513)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.0115)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.0082)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.0456)
# Finish Tuning!
# (2.6591479484724942, 18.803015465431965, 18.803015465431965)
# SNGCCA Started!
# 0.95 0.0
# 0.8 0.0
# 0.7934920476158722 0.0
# 6
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0072)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.0076)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.0098)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.0064)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.0104)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0092)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0066)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0064)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0059)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.0069)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.0062)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.0070)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.0070)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.0100)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.0077)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0073)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0076)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0096)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0081)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.0081)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.0063)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.0070)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.0087)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.0078)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.0075)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.0077)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.0067)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.0073)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.0082)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.0072)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.0087)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.0075)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.0090)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.0064)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.0073)
# Finish Tuning!
# (1.0, 1.0, 49.99999999999999)
# SNGCCA Started!
# 0.6833333333333333 0.0
# 0.09523809523809522 0.0
# -0.06415002990995841 0.0
# 8
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0096)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.0078)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.0098)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.0079)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.0067)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0079)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0087)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0069)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0081)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.0071)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.0084)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.0072)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.0084)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.0073)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.0078)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0107)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0080)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0078)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0057)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.0066)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.0067)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.0064)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.0068)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.0077)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.0074)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.0069)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.0070)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.0083)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.0074)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.0081)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.0087)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.0074)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.0078)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.0085)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.0081)
# Finish Tuning!
# (2.6591479484724942, 2.6591479484724942, 2.6591479484724942)
# SNGCCA Started!
# 0.6666666666666666 0.0
# 0.23076923076923075 0.0
# 0.11785113019775792 0.0
# 10
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# Sparsity selection number= 1 hyperparams= (1.0, 1.0, 1.0) obj= tensor(0.0091)
# Sparsity selection number= 2 hyperparams= (1.0, 1.0, 2.6591479484724942) obj= tensor(0.0083)
# Sparsity selection number= 3 hyperparams= (1.0, 1.0, 7.071067811865475) obj= tensor(0.0063)
# Sparsity selection number= 4 hyperparams= (1.0, 1.0, 18.803015465431965) obj= tensor(0.0084)
# Sparsity selection number= 5 hyperparams= (1.0, 1.0, 49.99999999999999) obj= tensor(0.0077)
# Sparsity selection number= 6 hyperparams= (1.0, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0084)
# Sparsity selection number= 7 hyperparams= (1.0, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0066)
# Sparsity selection number= 8 hyperparams= (1.0, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0074)
# Sparsity selection number= 9 hyperparams= (1.0, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0090)
# Sparsity selection number= 10 hyperparams= (1.0, 7.071067811865475, 7.071067811865475) obj= tensor(0.0077)
# Sparsity selection number= 11 hyperparams= (1.0, 7.071067811865475, 18.803015465431965) obj= tensor(0.0052)
# Sparsity selection number= 12 hyperparams= (1.0, 7.071067811865475, 49.99999999999999) obj= tensor(0.0074)
# Sparsity selection number= 13 hyperparams= (1.0, 18.803015465431965, 18.803015465431965) obj= tensor(0.0060)
# Sparsity selection number= 14 hyperparams= (1.0, 18.803015465431965, 49.99999999999999) obj= tensor(0.0073)
# Sparsity selection number= 15 hyperparams= (1.0, 49.99999999999999, 49.99999999999999) obj= tensor(0.0080)
# Sparsity selection number= 16 hyperparams= (2.6591479484724942, 2.6591479484724942, 2.6591479484724942) obj= tensor(0.0080)
# Sparsity selection number= 17 hyperparams= (2.6591479484724942, 2.6591479484724942, 7.071067811865475) obj= tensor(0.0085)
# Sparsity selection number= 18 hyperparams= (2.6591479484724942, 2.6591479484724942, 18.803015465431965) obj= tensor(0.0079)
# Sparsity selection number= 19 hyperparams= (2.6591479484724942, 2.6591479484724942, 49.99999999999999) obj= tensor(0.0076)
# Sparsity selection number= 20 hyperparams= (2.6591479484724942, 7.071067811865475, 7.071067811865475) obj= tensor(0.0086)
# Sparsity selection number= 21 hyperparams= (2.6591479484724942, 7.071067811865475, 18.803015465431965) obj= tensor(0.0092)
# Sparsity selection number= 22 hyperparams= (2.6591479484724942, 7.071067811865475, 49.99999999999999) obj= tensor(0.0059)
# Sparsity selection number= 23 hyperparams= (2.6591479484724942, 18.803015465431965, 18.803015465431965) obj= tensor(0.0076)
# Sparsity selection number= 24 hyperparams= (2.6591479484724942, 18.803015465431965, 49.99999999999999) obj= tensor(0.0069)
# Sparsity selection number= 25 hyperparams= (2.6591479484724942, 49.99999999999999, 49.99999999999999) obj= tensor(0.0061)
# Sparsity selection number= 26 hyperparams= (7.071067811865475, 7.071067811865475, 7.071067811865475) obj= tensor(0.0070)
# Sparsity selection number= 27 hyperparams= (7.071067811865475, 7.071067811865475, 18.803015465431965) obj= tensor(0.0069)
# Sparsity selection number= 28 hyperparams= (7.071067811865475, 7.071067811865475, 49.99999999999999) obj= tensor(0.0064)
# Sparsity selection number= 29 hyperparams= (7.071067811865475, 18.803015465431965, 18.803015465431965) obj= tensor(0.0069)
# Sparsity selection number= 30 hyperparams= (7.071067811865475, 18.803015465431965, 49.99999999999999) obj= tensor(0.0088)
# Sparsity selection number= 31 hyperparams= (7.071067811865475, 49.99999999999999, 49.99999999999999) obj= tensor(0.0079)
# Sparsity selection number= 32 hyperparams= (18.803015465431965, 18.803015465431965, 18.803015465431965) obj= tensor(0.0056)
# Sparsity selection number= 33 hyperparams= (18.803015465431965, 18.803015465431965, 49.99999999999999) obj= tensor(0.0083)
# Sparsity selection number= 34 hyperparams= (18.803015465431965, 49.99999999999999, 49.99999999999999) obj= tensor(0.0077)
# Sparsity selection number= 35 hyperparams= (49.99999999999999, 49.99999999999999, 49.99999999999999) obj= tensor(0.0094)
# Finish Tuning!
# (49.99999999999999, 49.99999999999999, 49.99999999999999)
# SNGCCA Started!
# 0.48333333333333334 0.0
# 0.06060606060606061 0.0
# -0.18984047621562894 0.0

# %%
print(ACC_list)
print(FS_list)
print(MCC_list)
# Out:
# [[0.95, 0.0], [0.6833333333333333, 0.0], [0.6666666666666666, 0.0], [0.48333333333333334, 0.0]]
# [[0.8, 0.0], [0.09523809523809522, 0.0], [0.23076923076923075, 0.0], [0.06060606060606061, 0.0]]
# [[0.7934920476158722, 0.0], [-0.06415002990995841, 0.0], [0.11785113019775792, 0.0], [-0.18984047621562894, 0.0]]

# %%
## Scenario 3
## Evaluation params
ACC_list = []
FS_list = []
MCC_list = []

for i in range(2,11,2):
    print(i)
    FS = []
    MCC = []
    ACC = []
    N = 400
    views = create_synthData_multi(i=i, data_type=2,N=400, p=20, q=20, r=20)    
    print(f'input views shape :')
    for i, view in enumerate(views):
        print(f'view_{i} :  {view.shape}')
        view = view.to("cpu")

    ## train hyper
    b0, obj = Solver.tune_hyper(x_list=views, set_params=5,iter=50)
    print(b0)

    print("SNGCCA Started!")
    for rep in range(1):
        if (rep + 1) % 100 == 0:
            print("REP=", rep + 1)

        ## fit results
        u = Solver._get_outputs(views, 1e-7, 100, b0)

        Label = torch.cat([torch.ones(2, dtype=torch.bool), torch.zeros(18, dtype=torch.bool)])
        acc,f1,mcc = FS_MCC(u, Label)
        ACC.append(acc)
        FS.append(f1)
        MCC.append(mcc)

    macc = np.mean(ACC)
    sdacc = np.std(ACC)
    print(macc, sdacc)
    ACC_list.append([macc,sdacc])

    mf = np.mean(FS)
    sdf = np.std(FS)
    print(mf, sdf)
    FS_list.append([mf,sdf])

    mmcc = np.mean(MCC)
    sdmcc = np.std(MCC)
    print(mmcc, sdmcc)
    MCC_list.append([mmcc, sdmcc])
# Out:
# 2
# input views shape :
# view_0 :  torch.Size([400, 20])
# view_1 :  torch.Size([400, 20])
# view_2 :  torch.Size([400, 20])
# Start Hyperparams Tuning
# C:\Users\Programer\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\synth_data.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   views = [torch.tensor(view).to(device) for view in views]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 20
#      17     view = view.to("cpu")
#      19 ## train hyper
# ---> 20 b0, obj = Solver.tune_hyper(x_list=views, set_params=5,iter=50)
#      21 print(b0)
#      23 print("SNGCCA Started!")
#
# File ~\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\main.py:62, in Solver.tune_hyper(self, x_list, set_params, eps, iter, k)
#      59     non_fold_index = [num for num in shuffled_index if num not in fold_index[i]]
#      60     train_data.append(view[non_fold_index, :])
# ---> 62 u = self.SNGCCA.fit(train_data,eps,iter,aa,logging=0)
#      64 # Save iterations
#      65 ## calculate K,cK for validation set
#      66 K_test = []
#
# File ~\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\sngcca.py:129, in SNGCCA.fit(self, views, eps, maxit, b, loss, early_stopping, patience, logging)
#     126 chk = 1
#     127 while chk == 1:
# --> 129     u_norm = self._optim(i,self.u_list[i],grad,gamma,b[i],view_len=view.shape[1],loss=loss)
#     130     Xu_new = view.to(self.device) @ u_norm
#     132     sigma = None
#
# File ~\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\sngcca.py:206, in SNGCCA._optim(self, i, u, grad, gamma, b, view_len, loss)
#     203     self.Adam_V[i] = v
#     204     v_new = torch.reshape(u + gamma * m / (torch.sqrt(v) + 1e-8), (-1,))
# --> 206 u_new = torch.reshape(self.projL1(v_new, b), (view_len, 1))
#     207 u_norm = u_new / torch.norm(u_new, p=2)
#     208 return u_norm
#
# File ~\Documents\GitHub\SGCCA_HSIC\SGCCA_HSIC\sngcca.py:23, in SNGCCA.projL1(self, v, b)
#      21 u, indices = torch.sort(torch.abs(v), descending=True)
#      22 sv = torch.cumsum(u, dim=0)
# ---> 23 rho = torch.sum(u > (sv - b) / torch.arange(1, len(u) + 1).to(self.device), dim=0)
#      24 theta = torch.max(torch.zeros_like(sv), (sv[rho - 1] - b) / rho)
#      25 w = torch.sign(v) * torch.max(torch.abs(v) - theta, torch.zeros_like(v))
#
# KeyboardInterrupt:

# %%
print(ACC_list)
print(FS_list)
print(MCC_list)
# Out:
# [[0.95, 0.0], [0.6666666666666666, 0.0], [0.6333333333333333, 0.0], [0.6, 0.0]]
# [[0.8, 0.0], [0.09090909090909091, 0.0], [0.21428571428571427, 0.0], [0.14285714285714288, 0.0]]
# [[0.7934920476158722, 0.0], [-0.07537783614444091, 0.0], [0.09222859518214328, 0.0], [-0.02305714879553582, 0.0]]
