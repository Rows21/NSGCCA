# %%
import torch
import numpy as np

from validation_method import eval

# %%
num = 5
tol = 100


print('100*100*5/Linear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Linear/100_100_5/'
u1 = np.genfromtxt(path + 'u1.csv', delimiter=',')[1:,1:]
u2 = np.genfromtxt(path + 'u2.csv', delimiter=',')[1:,1:]
u3 = np.genfromtxt(path + 'u3.csv', delimiter=',')[1:,1:]
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(100):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))

print('100*100*5/NonLinear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Nonlinear/100_100_5/'
u1 = np.genfromtxt(path + 'u1.csv', delimiter=',')[1:,1:]
u2 = np.genfromtxt(path + 'u2.csv', delimiter=',')[1:,1:]
u3 = np.genfromtxt(path + 'u3.csv', delimiter=',')[1:,1:]
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(100):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))
# Out:
# 100*100*5/Linear
# Specificity: 0.9723599299969246 0.017965632798853097
# Precision: 0.8653333333333335 0.0879292645002536
# Recall: 0.024655077644380543 0.0025184677056027346
# FS: 0.047943820589925704 0.004894968302147941
# MCC: -0.006128610490138681 0.042919384879431324
# 100*100*5/NonLinear
# Specificity: 0.9766614406653719 0.01785838975844743
# Precision: 0.8966666666666667 0.07681145747868609
# Recall: 0.0252088548260632 0.002125194706795092
# FS: 0.04903873354342776 0.00413424958155168
# MCC: 0.0037707172826910505 0.03928429245055501

# %%
num = 5
tol = 200


print('100*100*10/Linear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Linear/100_200_5/'
u1 = np.genfromtxt(path + 'rgcca_u1.csv', delimiter=',')[1:,1:]
u2 = np.genfromtxt(path + 'rgcca_u2.csv', delimiter=',')[1:,1:]
u3 = np.genfromtxt(path + 'rgcca_u3.csv', delimiter=',')[1:,1:]
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(100):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))

print('100*100*10/NonLinear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Nonlinear/100_200_5/'
u1 = np.genfromtxt(path + 'rgcca_u1.csv', delimiter=',')[1:,1:]
u2 = np.genfromtxt(path + 'rgcca_u2.csv', delimiter=',')[1:,1:]
u3 = np.genfromtxt(path + 'rgcca_u3.csv', delimiter=',')[1:,1:]
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(100):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))
# Out:
# 100*100*10/Linear
# Specificity: 0.974639392295976 0.01801503216205335
# Precision: 0.8780000000000001 0.0869508162379425
# Recall: 0.024936726730220266 0.0024307839551627134
# FS: 0.04849574125194067 0.004727517849958155
# MCC: -0.0009947149824387667 0.04223158077542332
# 100*100*10/NonLinear
# Specificity: 0.9783662610515078 0.018961056639440643
# Precision: 0.904 0.08343726851819741
# Recall: 0.025461947137543007 0.002384602569314977
# FS: 0.04952857568884314 0.004635004043455278
# MCC: 0.00795733511200465 0.04286048281083685

# %%
num = 5
tol = 100


print('100*100*10/Linear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Linear/400_100_5/'
u1 = np.genfromtxt(path + 'u1.csv', delimiter=',')
u2 = np.genfromtxt(path + 'u2.csv', delimiter=',')
u3 = np.genfromtxt(path + 'u3.csv', delimiter=',')
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(50):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))

print('100*100*10/NonLinear')
path = 'C:/Users/Programer/Documents/GitHub/SGCCA_HSIC/SNGCCA/Simulation/Nonlinear/400_100_5/'
u1 = np.genfromtxt(path + 'u1.csv', delimiter=',')
u2 = np.genfromtxt(path + 'u2.csv', delimiter=',')
u3 = np.genfromtxt(path + 'u3.csv', delimiter=',')
Label = torch.cat([torch.ones(num, dtype=torch.bool), torch.zeros(tol-num, dtype=torch.bool)])

FS = []
MCC = []
PRE = []
REC = []
SPE = []
for i in range(50):
    u = [torch.tensor(u1[i]),torch.tensor(u2[i]),torch.tensor(u3[i])]
    spe, pre, rec, acc, f1, mcc = eval(u, Label)
    SPE.append(spe)
    PRE.append(pre)
    REC.append(rec)
    FS.append(f1)
    MCC.append(mcc)

print("Specificity:",np.mean(SPE),np.std(SPE))
print("Precision:",np.mean(PRE),np.std(PRE))
print("Recall:",np.mean(REC),np.std(REC))
print("FS:",np.mean(FS),np.std(FS))
print("MCC:",np.mean(MCC),np.std(MCC))
# Out:
# 100*100*10/Linear
# Specificity: 0.9921461163012115 0.008086792252788366
# Precision: 0.856 0.1462782736202931
# Recall: 0.6139490895493309 0.1804205493765864
# FS: 0.7074340190912303 0.1653310909900049
# MCC: 0.7029306166286275 0.17135577126447157
# 100*100*10/NonLinear
# Specificity: 0.9916665853572106 0.00949340337482184
# Precision: 0.8546666666666666 0.1647570602095367
# Recall: 0.3941067020568417 0.11295427448767509
# FS: 0.5372905165509878 0.13887542797323438
# MCC: 0.547799202533785 0.15220102080791878
